# %% [markdown]
# Import necessary libraries

# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np
import matplotlib.pyplot as plt


LOG.propagate = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **Connect to the board via BLE**

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()
# Out:
# 2025-03-10 03:36:11,117 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:81:80:25:12:64
# 2025-03-10 03:36:15,255 | INFO     |: Connected to c0:81:80:25:12:64

# %% [markdown]
# Read from TOF1

# %%
ble.send_command(CMD.GET_TOF1, "")
distance1 = int(ble.receive_string(ble.uuid['RX_STRING']))
print(f"Measured distance: {distance1}")
# Out:
# Measured distance: 2297

# %% [markdown]
# Read from TOF2

# %%
ble.send_command(CMD.GET_TOF2, "")
distance2 = int(ble.receive_string(ble.uuid['RX_STRING']))
print(f"Measured distance: {distance2}")

# %% [markdown]
# READ N TOF entries

# %%
ble.send_command(CMD.GET_TOF_300, "50")
# Out:
# 2025-03-10 01:38:35,191 | INFO     |: Disconnected from C0:81:80:25:12:64

# %%
tof_timestamps = []
distance1 = []
distance2 = []
def extract_distance_data(uuid, byte_array):
    string = byte_array.decode("utf-8") 
    split_str = string.split("|")
    tof_timestamps.append(int(split_str[0]))
    distance1.append(int(split_str[1]))
    distance2.append(int(split_str[2]))
ble.start_notify(ble.uuid['RX_STRING'], extract_distance_data)

# %%
print(tof_timestamps)
# Out:
# []

# %%
ble.stop_notify(ble.uuid['RX_STRING'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ble.stop_notify(ble.uuid['RX_STRING'])
#
# File ~\Classes\ECE_4160\ece4160\code\lab5\jupyter\ble.py:84, in BaseBLEController.stop_notify(self, uuid)
#      83 def stop_notify(self, uuid):
# ---> 84     self._wait(self.device._stop_notify(uuid))
#
# File ~\Classes\ECE_4160\ece4160\code\lab5\jupyter\base_ble.py:27, in wait_b(coroutine)
#      26 def wait_b(coroutine):
# ---> 27     return asyncio.run(coroutine)
#
# File ~\Classes\ECE_4160\labs\FastRobots_ble\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\Classes\ECE_4160\labs\FastRobots_ble\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.752.0_x64__qbz5n2kfra8p0\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.752.0_x64__qbz5n2kfra8p0\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File ~\Classes\ECE_4160\ece4160\code\lab5\jupyter\base_ble.py:135, in BLEAsyncDevice._stop_notify(self, uuid)
#     133 async def _stop_notify(self, uuid):
#     134     if self.client and self.client.is_connected:
# --> 135         await self.client.stop_notify(uuid)
#     136     else:
#     137         raise Exception("Not connected to a BLE device")
#
# File ~\Classes\ECE_4160\labs\FastRobots_ble\Lib\site-packages\bleak\__init__.py:862, in BleakClient.stop_notify(self, char_specifier)
#     846 async def stop_notify(
#     847     self, char_specifier: Union[BleakGATTCharacteristic, int, str, uuid.UUID]
#     848 ) -> None:
#     849     """
#     850     Deactivate notification/indication on a specified characteristic.
#     851
#    (...)
#     860         stopped some time before the device disconnects.
#     861     """
# --> 862     await self._backend.stop_notify(char_specifier)
#
# File ~\Classes\ECE_4160\labs\FastRobots_ble\Lib\site-packages\bleak\backends\winrt\client.py:1027, in BleakClientWinRT.stop_notify(self, char_specifier)
#    1017     raise BleakCharacteristicNotFoundError(char_specifier)
#    1019 _ensure_success(
#    1020     await characteristic.obj.write_client_characteristic_configuration_descriptor_async(
#    1021         GattClientCharacteristicConfigurationDescriptorValue.NONE
#    (...)
#    1024     f"Could not stop notify on {characteristic.handle:04X}",
#    1025 )
# -> 1027 event_handler_token = self._notification_callbacks.pop(characteristic.handle)
#    1028 characteristic.obj.remove_value_changed(event_handler_token)
#
# KeyError: 14

# %% [markdown]
# Plot Raw Data

# %%
# Cast to correct data type
tof_timestamps = np.array(tof_timestamps, dtype=int)  
distance1 = np.array(distance1, dtype=int)      
distance2 = np.array(distance2, dtype=int)      

plt.figure(figsize=(10, 5))  # Set figure size

# Define how many ticks you want
num_ticks = 5  # Adjust for spacing

# Plot all three lines on the same graph
plt.plot(tof_timestamps, distance1, label='distance1', linestyle='-', marker='o')
plt.plot(tof_timestamps, distance2, label='distance2', linestyle='--', marker='s')

# Labels and title
plt.xlabel('Timestamp (ms)')
plt.ylabel('Value')
plt.title('Distance 1, Distance 2 over Time')
plt.legend()

# Reduce the number of ticks on x and y axes
plt.xticks(np.linspace(tof_timestamps.min(), tof_timestamps.max(), num_ticks))
plt.yticks(np.linspace(min(distance1.min(), distance2.min()), 
                       max(distance1.max(), distance2.max()), num_ticks))

plt.grid(True)  # Add grid for readability
plt.tight_layout()
plt.show()

# %% [markdown]
# Calculate Average Distance, Ranging Time, Standard deviation

# %%
distance1_avg = np.mean(distance1)
average_diff_ms = np.mean(np.diff(tof_timestamps))
std_dev = np.std(distance1)

print(f"distance1 avg: {distance1_avg}")
print(f"ranging time: {average_diff_ms}")
print(f"Standard Deviation: {std_dev:.4f}")
# Out:
# distance1 avg: 3111.79
# ranging time: 95.18181818181819
# Standard Deviation: 3.7021
# 2025-02-24 23:53:00,176 | INFO     |: Disconnected from C0:81:80:25:12:64

# %% [markdown]
# Plotting distance, ranging time, std dev

# %%
# Data from the table
actual_distance = np.array([50, 100, 300, 500, 700, 1500, 2000, 3000])  # in mm
tof_mean = np.array([52.0, 115.11, 316.18, 522.89, 717.57, 1537.04, 2078.4, 3111.79])  # short distance (100 avg)
ranging_time = np.array([96.90, 96.48, 96.67, 97.02, 96.86, 95.22, 95.32, 95.18])  # in ms
std_deviation = np.array([1.15, 1.32, 1.25, 1.04, 1.21, 1.97, 1.99, 3.70])  # in mm

# Create subplots
plt.figure(figsize=(18, 15))

# Plot 1: TOF Mean with y = x line
plt.subplot(3, 1, 1)
plt.plot(actual_distance, tof_mean, marker='o', color='b', label='TOF Mean (100 avg)')
plt.plot(actual_distance, actual_distance, linestyle='--', color='orange', label='Ideal y = x')
plt.xlabel('Actual Distance (mm)')
plt.ylabel('TOF Mean (mm)')
plt.title('TOF Mean vs Actual Distance')
plt.grid(True)
plt.legend()

# Plot 2: Standard Deviation
plt.subplot(3, 1, 2)
plt.plot(actual_distance, std_deviation, marker='o', color='r', label='Standard Deviation')
plt.xlabel('Actual Distance (mm)')
plt.ylabel('Standard Deviation (mm)')
plt.title('Standard Deviation vs Actual Distance')
plt.grid(True)
plt.legend()

# Plot 3: Ranging Time
plt.subplot(3, 1, 3)
plt.plot(actual_distance, ranging_time, marker='o', color='g', label='Ranging Time')
plt.xlabel('Actual Distance (mm)')
plt.ylabel('Ranging Time (ms)')
plt.title('Ranging Time vs Actual Distance')
plt.grid(True)
plt.legend()

# Display plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for 50 cm measurements
ranging_time = np.array([20, 30, 45, 60, 90])  # Ranging times in milliseconds
measured_values = np.array([57.2, 57.0, 55.2, 53.6, 52.1])  # Example measured values in cm
std_deviation = np.array([3.5, 3.0, 2.0, 1.5, 1.12])  # Standard deviation for each measurement

# Create the plot
plt.figure(figsize=(10, 7))
plt.errorbar(ranging_time, measured_values, yerr=std_deviation, fmt='o-', capsize=5, label='Measured Value')

# Plot formatting
plt.title('Measured Value vs. Ranging Time with Deviation (50 cm)')
plt.xlabel('Ranging Time (ms)')
plt.ylabel('Measured Value (cm)')
plt.legend()
plt.grid(True)
plt.show()

# %%
control_timestamps = []
i_err = []
p_err = []
speed = []
dt = []

def extract_control_data(uuid, byte_array):
    string = byte_array.decode("utf-8") 
    split_str = string.split("|")
    control_timestamps.append(int(split_str[0]))
    speed.append(int(split_str[1]))
    p_err.append(int(split_str[2]))
    i_err.append(int(split_str[3]))
    dt.append(int(split_str[4]))
    
ble.start_notify(ble.uuid['RX_STRING'], extract_control_data)

# %%
ble.stop_notify(ble.uuid['RX_STRING'])

# %%
ble.send_command(CMD.FORWARD_CONTROLLED, "0.1|0.001|80|300|20|40|400")

# %%
ble.send_command(CMD.FORWARD, "140|110")

# %%
ble.send_command(CMD.BACKWARD, "200")

# %%
ble.send_command(CMD.STOP, "")
# Out:
# 2025-03-10 03:35:49,303 | INFO     |: Disconnected from C0:81:80:25:12:64

# %%
print("timestamps:")
print(control_timestamps)
print("speed:")
print(speed)
print("p err:")
print(p_err)
print("i err:")
print(i_err)
print("dt: ")
print(dt)
# Out:
# timestamps:
# [47968, 47984, 48012, 48028, 48053, 48080, 48096, 48119, 48141, 48157, 48184, 48205, 48221, 48248, 48265, 48281, 48303, 48325, 48344, 48360, 48387, 48404, 48432, 48448, 48470, 48492, 48514, 48536, 48552, 48568, 48596, 48612, 48631, 48647, 48664, 48685, 48707, 48729, 48756, 48773, 48795, 48815, 48831, 48853, 48880, 48902, 48924, 48946, 48965, 48981, 49003, 49025, 49047, 49068, 49085, 49107, 49129, 49150, 49172, 49196, 49212, 49234, 49256, 49278, 49299, 49321, 49343, 49370, 49392, 49424, 49443, 49465, 49486, 49498, 49531, 49548, 49564, 49591, 49617, 49640, 49661, 49678, 49700, 49727, 49743, 49767, 49783, 49805, 49832, 49849, 49870, 49892, 49916, 49932, 49954, 49970, 50002]
# speed:
# [80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 0, -45, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80, -80]
# p err:
# [1951, 1919, 1857, 1857, 1831, 1802, 1789, 1780, 1752, 1741, 1731, 1693, 1686, 1669, 1643, 1628, 1593, 1574, 1547, 1549, 1522, 1500, 1479, 1476, 1434, 1400, 1377, 1372, 1342, 1322, 1288, 1272, 1238, 1229, 1206, 1177, 1151, 1129, 1094, 1059, 1049, 1015, 988, 958, 922, 903, 871, 825, 808, 766, 754, 726, 691, 667, 626, 593, 541, 521, 506, 445, 402, 387, 369, 327, 292, 243, 216, 194, 159, 121, 76, 31, -8, -38, -64, -96, -107, -159, -180, -232, -224, -266, -296, -284, -277, -236, -243, -230, -218, -211, -199, -164, -229, -221, -213, -208, -201]
# i err:
# [7804, 25075, 56644, 75214, 108172, 140608, 158498, 188758, 211534, 230685, 263574, 283890, 305808, 332512, 347299, 366835, 392323, 412785, 428255, 448392, 478832, 496832, 520496, 536732, 565412, 589212, 608490, 623582, 637002, 655510, 678694, 690142, 704998, 719746, 739042, 763759, 784477, 803670, 824456, 836105, 849742, 859892, 872736, 890938, 908456, 920195, 934131, 944031, 952111, 960537, 971847, 983463, 994519, 1004524, 1013288, 1025741, 1035479, 1043294, 1050378, 1057498, 1062724, 1069303, 1075945, 1081177, 1086141, 1091244, 1095564, 1099250, 1101635, 1103692, 1104528, 1104962, 0, -456, -1800, -2568, -3745, -7084, -10504, -13520, -15984, -18910, -23054, -27598, -30091, -33631, -36304, -39984, -43908, -46651, -49835, -52295, -55501, -57711, -61119, -64447, -69472]
# dt:
# [4, 9, 17, 10, 18, 18, 10, 17, 13, 11, 19, 12, 13, 16, 9, 12, 16, 13, 10, 13, 20, 12, 16, 11, 20, 17, 14, 11, 10, 14, 18, 9, 12, 12, 16, 21, 18, 17, 19, 11, 13, 10, 13, 19, 19, 13, 16, 12, 10, 11, 15, 16, 16, 15, 14, 21, 18, 15, 14, 16, 13, 17, 18, 16, 17, 21, 20, 19, 15, 17, 11, 14, 13, 12, 21, 8, 11, 21, 19, 13, 11, 11, 14, 16, 9, 15, 11, 16, 18, 13, 16, 15, 14, 10, 16, 16, 25]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert lists to numpy arrays for better performance
control_timestamps = np.array(control_timestamps)
speed = np.array(speed)
p_err = np.array(p_err)
i_err = np.array(i_err)

# Plot control timestamps vs. speed
plt.figure(figsize=(10, 5))
plt.plot(control_timestamps, speed, marker='o', linestyle='-', label='Speed')
plt.xlabel('Control Timestamps')
plt.ylabel('Speed')
plt.title('Control Timestamps vs Speed')
plt.legend()
plt.grid(True)
plt.show()

# Plot control timestamps vs. p_err
plt.figure(figsize=(10, 5))
plt.plot(control_timestamps, p_err, marker='s', linestyle='-', label='P Error', color='r')
plt.xlabel('Control Timestamps')
plt.ylabel('P Error')
plt.title('Control Timestamps vs P Error')
plt.legend()
plt.grid(True)
plt.show()

# Plot control timestamps vs. i_err
plt.figure(figsize=(10, 5))
plt.plot(control_timestamps, i_err, marker='s', linestyle='-', label='I Error', color='r')
plt.xlabel('Control Timestamps')
plt.ylabel('I Error')
plt.title('Control Timestamps vs I Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(p_err)
# Out:
# [350, 363, 331, 366, 349, 390, 382, 347, 360, 382, 343, 359, 401, 335, 364, 371, 373, 372, 421, 392, 375, 408, 436, 441, 449, 468, 475, 505, 532, 523, 586, 588, 582, 643, 540, 519, 542, 365, 391, 267, 319, 276, 294, 280, 286, 278, 296, 265, 263, 268, 265, 240, 242, 235, 239, 231, 224, 215, 165, 169, 175, 163, 157, 162, 162, 151, 150, 151, 147, 145, 147, 138, 145, 141, 135, 140, 146, 148, 161, 161, 167, 169, 169, 167, 184, 188, 188, 186, 190, 189, 205, 211, 239, 277, 293, 413, 599, 649, 674, 677, 687, 697, 703, 694, 706, 712, 709, 709, 715, 734, 721, 710, 719, 703, 706, 692, 671, 655, 647, 654, 645, 623, 569, 493, 501, 494, 358, 278, 232, 194, 127, 88]

# %%
print(i_err)
# Out:
# [652, 17206, 48265, 110217, 177225, 242555, 307047, 375141, 441166, 507999, 567339, 632105, 690917, 756197, 820832, 881634, 946074, 1007844, 1073455, 1138499, 1197829, 1257933, 1319904, 1384409, 1445405, 1503530, 1550188, 1595080, 1635575, 1670819, 1702769, 1731160, 1757504, 1782408, 1805376, 1826720, 1845878, 1862531, 1877637, 1890832, 1901620, 1910728, 1919009, 1927265, 1935435, 1942579, 1948903, 1954423, 1959246, 1963852, 1968544, 1972930, 1977634, 1981726, 1985315, 1987947, 1990851, 1994157, 1996649, 1998696, 2000670, 2002455, 2003879]
